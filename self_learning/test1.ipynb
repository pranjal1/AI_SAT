# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

X = pd.read_csv('house_data.csv')
price = X['price']
bedrooms = X['bedrooms']
sqft_living = X['sqft_living']


plt.subplot(211)
plt.plot(sqft_living,price)

plt.subplot(212)
plt.plot(bedrooms,price)

# %%
X.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
longitude = X['longitude']
longitude
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-c5a45e18587f> in <module>()
# ----> 1 longitude = X['longitude']
#       2 longitude
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
# ...

# %%
X
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1230000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
list(X)
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
X = pd.read_csv('./datasets/housing/housing.csv')
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
list(X)
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'ocean_proximity']

# %%
housing_median_age = X['housing_median_age']
median_house_value = X['median_house_value']
total_rooms = X['total_rooms']


plt.subplot(211)
plt.scatter(housing_median_age,median_house_value,s=1)

plt.subplot(212)
plt.scatter(total_rooms,median_house_value,s=1)

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
X["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
X.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
X.hist(bins=50, figsize=(20,15))
plt.show()

# %%
import pandas as pd
X = pd.read_csv('./datasets/housing/housing.csv')
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
X.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
list(X)
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'ocean_proximity']

# %%
X['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
import numpy as np
X["income_cat"] = np.ceil(X["median_income"] / 1.5)

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    income_cat
# 0         6.0
# 1         6.0
# 2         5.0
# ...

# %%
X['income_cat'].value_counts()
# Out:
# 3.0     7236
# 2.0     6581
# 4.0     3639
# 5.0     1423
# 1.0      822
# 6.0      532
# 7.0      189
# 8.0      105
# 9.0       50
# 11.0      49
# 10.0      14
# Name: income_cat, dtype: int64

# %%
X["income_cat"].where(X["income_cat"] < 5, 5.0, inplace=True)

# %%
X['income_cat'].value_counts()
# Out:
# 3.0    7236
# 2.0    6581
# 4.0    3639
# 5.0    2362
# 1.0     822
# Name: income_cat, dtype: int64

# %%
import matplotlib.pyplot as plt
X['income_cat'].hist(figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# %%
print split
# Out:
# StratifiedShuffleSplit(n_splits=1, random_state=42, test_size=0.2,
#             train_size=None)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt

X = pd.read_csv('./datasets/housing/housing.csv')

X["income_cat"] = np.ceil(X["median_income"] / 1.5)
X["income_cat"].where(X["income_cat"] < 5, 5.0, inplace=True)


split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(X, X["income_cat"]):
    strat_train_set = X.loc[train_index]
    strat_test_set = X.loc[test_index]
    
strat_train_set["income_cat"].value_counts()
# Out:
# 3.0    5789
# 2.0    5265
# 4.0    2911
# 5.0    1889
# 1.0     658
# Name: income_cat, dtype: int64

# %%
strat_test_set["income_cat"].value_counts()
# Out:
# 3.0    1447
# 2.0    1316
# 4.0     728
# 5.0     473
# 1.0     164
# Name: income_cat, dtype: int64

# %%
X['income_cat'].hist(figsize=(20,15))
plt.show()

# %%
strat_train_set["income_cat"].hist(figsize=(20,15))
plt.show()

# %%
strat_test_set["income_cat"].hist(figsize=(20,15))
plt.show()

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)

# %%
list(strat_test_set)
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'ocean_proximity']

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt

X = pd.read_csv('./datasets/housing/housing.csv')

X["income_cat"] = np.ceil(X["median_income"] / 1.5)
X["income_cat"].where(X["income_cat"] < 5, 5.0, inplace=True)


split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(X, X["income_cat"]):
    strat_train_set = X.loc[train_index]
    strat_test_set = X.loc[test_index]
    
Y = strat_train_set.copy()

# %%
Y.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17606    -121.89     37.29                38.0       1568.0           351.0
# 18632    -121.93     37.05                14.0        679.0           108.0
# 14650    -117.20     32.77                31.0       1952.0           471.0
# 3230     -119.61     36.31                25.0       1847.0           371.0
# 3555     -118.59     34.23                17.0       6592.0          1525.0
#
#        population  households  median_income  median_house_value  \
# 17606       710.0       339.0         2.7042            286600.0
# 18632       306.0       113.0         6.4214            340600.0
# 14650       936.0       462.0         2.8621            196900.0
# 3230       1460.0       353.0         1.8839             46300.0
# 3555       4459.0      1463.0         3.0347            254500.0
#
#       ocean_proximity  income_cat
# 17606       <1H OCEAN         2.0
# 18632       <1H OCEAN         5.0
# ...

# %%
Y.plot(kind="scatter", x="longitude", y="latitude")

# %%
Y.plot(kind="scatter", x="longitude", y="latitude",alpha = 0.1)

# %%
Y.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
    s=housing["population"]/100, label="population", figsize=(10,7),
    c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8a81fe30f772> in <module>()
#       1 Y.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
# ----> 2     s=housing["population"]/100, label="population", figsize=(10,7),
#       3     c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
#       4 )
#       5 plt.legend()
#
# NameError: name 'housing' is not defined

# %%
Y.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
    s=Y["population"]/100, label="population", figsize=(10,7),
    c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
Y.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
    s=Y["population"]/100, label="population", figsize=(10,7),
    c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
test_x = np.arange(10)
test_y = np.random.randint(10,size=10)

fig, ax = plt.subplots()
im = ax.scatter(test_x,test_y,c = test,label='testing color',s=test_x*20)

# Add a colorbar
fig.colorbar(im, ax=ax)
plt.legend()
test_y
# Out:
# array([3, 2, 7, 3, 7, 5, 9, 1, 9, 2])

# %%
test_y
# Out:
# array([3, 2, 7, 3, 7, 5, 9, 1, 9, 2])

# %%
corr_matrix = Y.corr()
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924478           -0.105848     0.048871
# latitude            -0.924478  1.000000            0.005766    -0.039184
# housing_median_age  -0.105848  0.005766            1.000000    -0.364509
# total_rooms          0.048871 -0.039184           -0.364509     1.000000
# total_bedrooms       0.076598 -0.072419           -0.325047     0.929379
# population           0.108030 -0.115222           -0.298710     0.855109
# households           0.063070 -0.077647           -0.306428     0.918392
# median_income       -0.019583 -0.075205           -0.111360     0.200087
# median_house_value  -0.047432 -0.142724            0.114110     0.135097
# income_cat          -0.016243 -0.078848           -0.139385     0.221690
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.076598    0.108030    0.063070      -0.019583
# ...

# %%
from pandas.tools.plotting import scatter_matrix

attributes = ["median_house_value", "median_income","longitude","population"]
scatter_matrix(Y[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f71764b7f50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7175a41b10>]], dtype=object)

# %%
Y.plot(kind="scatter", x="median_income", y="median_house_value",
             alpha=0.4)
